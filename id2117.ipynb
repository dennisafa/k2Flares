# %%
from lightkurve import KeplerLightCurveFile
from george import kernels
from george.metrics import Metric
import matplotlib.pyplot as plt
import numpy as np
#import george
from astropy.stats import median_absolute_deviation

str = KeplerLightCurveFile.from_archive(211799258)
# Out:
# Found 1 File(s)
# Downloading URL https://mast.stsci.edu/api/v0/download/file?uri=mast:K2/url/missions/k2/lightcurves/c5/211700000/99000/ktwo211799258-c05_llc.fits to ./mastDownload/K2/ktwo211799258-c05_lc/ktwo211799258-c05_llc.fits ... [Done]

# %%
strPDC = str.PDCSAP_FLUX
strPDC.plot()
